# %% [markdown]
# <a href="https://colab.research.google.com/github/forestgolden/Ciencia-de-Dados/blob/main/PUC_Programa%C3%A7%C3%A3o_para_ci%C3%AAncia_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introdução

# %%
#Declaração de variável
variavel = 5
#Type verifica a variável
type(variavel)
# Out:
# int

# %%
#Type Casting
variavelfloat = float(variavel)
variavelfloat

#float()
#str()
#bool()
#int()
# Out:
# 5.0

# %%
#Comentário

"""
  Comentário
            Em
              Bloco
"""
# Out:
# '\n  Comentário\n            Em\n              Bloco\n'

# %% [markdown]
# #Listas

# %%
lista_vazia = []
lista_vazia2 = list()

# %%
#Verificar tipo
type(lista_vazia)
# Out:
# list

# %%
#Tamanho da lista
len(lista_vazia)
# Out:
# 0

# %%
#Criar lista com elementos
lista_cheia = [2,4,"Bruno", True]

# %%
#Acessar elementos, coloca-se o índice dentro
lista_cheia[0]
# Out:
# 2

# %%
#Alterar elementos
lista_cheia[0] = 6
lista_cheia
# Out:
# [6, 4, 'Bruno', True]

# %% [markdown]
# #Métodos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Append - acrescenta no FINAL da lista
lista_cheia.append("20")
lista_cheia
# Out:
# [6, 4, 'Bruno', True, '20']

# %%
#Clear - remove TODOS os elementos da lista
lista_cheia.clear()
lista_cheia
# Out:
# []

# %%
#Copy - Copia de uma lista para a outra
lista_cheia2 = [2,6,3,"Bruno", False]
lista_sem = lista_cheia2.copy()
lista_sem
# Out:
# [2, 6, 3, 'Bruno', False]

# %%
#Count - Contar quantidade de recorrência de um elemento
#Coloca-se o valor do elemento, NÃO A POSIÇÃO
lista_sem.count(2)
# Out:
# 1

# %%
# Extend - Inserir os elementos de uma lista para a outra
lista_sem.extend([45,"Lefis"])
lista_sem
# Out:
# [2, 6, 3, 'Bruno', False, 45, 'Lefis', 45, 'Lefis']

# %% [markdown]
# #Tupla

# %%
tuplavazia = ()
tuplavazia2 = tuple()

# %%
isinstance(tuplavazia, tuple)
# Out:
# True

# %%
len(tuplavazia)
# Out:
# 0

# %%
tuplacheia = (2,5,3,2, "Bruno", True)
tuplacheia2 = (4,6,2,1,7,9)

# %%
#Acessar os elementos da tupla
tuplacheia[2]
# Out:
# 3

# %% [markdown]
# #Métodos

# %%
tuplacheia.count(3)
# Out:
# 1

# %%
#Verifica a posição com base no elemento passado em parâmetro
tuplacheia.index(5)
# Out:
# 1

# %%
len(tuplacheia2)
# Out:
# 29

# %%
#a função não pode fazer o máximo se tiver
#string dentro da tupla
max(tuplacheia2)
# Out:
# 9

# %%
min(tuplacheia2)
# Out:
# 1

# %%
sum(tuplacheia2)
# Out:
# 29

# %%
#Converter uma tupla em lista
listadetupla = list(tuplacheia2)

# %%
type(listadetupla)
# Out:
# list

# %% [markdown]
# #Dicionário

# %%
#Iniciar dicionário vazio
dic_vazio1 = {}
dic_vazio2 = dict()

# %%
type(dic_vazio1)
# Out:
# dict

# %%
isinstance(dic_vazio2,dict)
# Out:
# True

# %%
#Criar dicionário com valores
dic_estados = {"MG":"Minas Gerais", "PR":"Paraná",
               "BA":"Bahia","RN":"Rio Grande do Norte",
               "AM":"Amazonas"}
dic_estados
# Out:
# {'AM': 'Amazonas',
#  'BA': 'Bahia',
#  'MG': 'Minas Gerais',
#  'PR': 'Paraná',
#  'RN': 'Rio Grande do Norte'}

# %%
#Acessar o dicionário através da chave
dic_estados["PR"]
# Out:
# 'Paraná'

# %%
dic_estados["AM"] = "Amazonass"
dic_estados["AM"]
# Out:
# 'Amazonass'

# %%
dic_estados["AM"] = "Amazonas"

# %% [markdown]
# ![image.png](data:image/png;base64,...)
